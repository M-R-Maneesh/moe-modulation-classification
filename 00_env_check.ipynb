# %% [markdown]
# <a href="https://colab.research.google.com/github/M-R-Maneesh/moe-modulation-classification/blob/main/00_env_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
print('Device name:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU only')
# Out:
# CUDA available: True
# Device name: Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Make sure Drive is mounted first:
# from google.colab import drive
# drive.mount('/content/drive')

PROJECT_DIR = '/content/drive/MyDrive/moe-modulation-classification'

folders = [
    'data/raw',
    'data/processed',
    'src/models',
    'experiments/exp1_baselines',
    'experiments/exp2_moe_indist',
    'experiments/exp3_zero_shot',
    'experiments/exp4_expert_usage',
    'experiments/exp5_efficiency',
    'notebooks',
    'results/checkpoints',
    'results/figures',
    'results/logs',
    'report',
]

for folder in folders:
    path = os.path.join(PROJECT_DIR, folder)
    os.makedirs(path, exist_ok=True)
    print('Created:', path)

print('\nDone. Folder structure:')
for root, dirs, files in os.walk(PROJECT_DIR):
    level = root.replace(PROJECT_DIR, '').count(os.sep)
    indent = '  ' * level
    print(f'{indent}{os.path.basename(root)}/')
# Out:
# Created: /content/drive/MyDrive/moe-modulation-classification/data/raw
# Created: /content/drive/MyDrive/moe-modulation-classification/data/processed
# Created: /content/drive/MyDrive/moe-modulation-classification/src/models
# Created: /content/drive/MyDrive/moe-modulation-classification/experiments/exp1_baselines
# Created: /content/drive/MyDrive/moe-modulation-classification/experiments/exp2_moe_indist
# Created: /content/drive/MyDrive/moe-modulation-classification/experiments/exp3_zero_shot
# Created: /content/drive/MyDrive/moe-modulation-classification/experiments/exp4_expert_usage
# Created: /content/drive/MyDrive/moe-modulation-classification/experiments/exp5_efficiency
# Created: /content/drive/MyDrive/moe-modulation-classification/notebooks
# Created: /content/drive/MyDrive/moe-modulation-classification/results/checkpoints
# Created: /content/drive/MyDrive/moe-modulation-classification/results/figures
# ...

# %%
import os
PROJECT_DIR = '/content/drive/MyDrive/moe-modulation-classification'
os.makedirs(PROJECT_DIR, exist_ok=True)

# %%
# !pip install -q h5py scikit-learn seaborn tqdm thop
